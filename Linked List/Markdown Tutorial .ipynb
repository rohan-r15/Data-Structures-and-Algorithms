# %% [markdown]
# ---
#
# # Topics Covered
#
# ---
#
# 1. <a href="#1.Headings">Heading</a>
# 2. <a href="#2.Block-Quotes(Indendation)">Block Quotes</a>
# 3. <a href="#3.Mathematical-Symbol">Mathematical Symbol</a>
# 4. <a href="#4.Line-Break">Line Break</a>
# 5. <a href="#5.Bold-and-Italic-Text">Bold and Italic Text</a>
# 6. <a href="#6.Horizontal-Lines">Horizontal Lines</a>
# 7. <a href="#7.Ordered-List">Ordered List</a>
# 8. <a href="#8.Unordered-List">Unordered List</a>
# 9. <a href="#9.Internal-and-External-Links">Internal and External Links</a>
# 10. <a href="#10.Image">Image</a>
# 11. [Video](#11.Video)
# 12. [Other Markdowns](#12.Other-Markdowns)
#
# ---

# %% [markdown]
# # 1.Headings

# %% [markdown]
# # Title
#
# ## Major Heading
#
# ### Subheading
#
# #### smaller
#
# ##### even smaller
#
# <h1> Tagged Heading, Title </h1>
# <h2> Tag Range h1 - h6 </h2>

# %% [markdown]
# [<a href="#Topics-Covered">Back to top</a>]
#
# ---

# %% [markdown]
# # 2.Block Quotes(Indendation)

# %% [markdown]
# Introduction to Jupyter Notebook
# >Juypter Notebook is famous for doing [data analysis](
# https://towardsdatascience.com/an-extensive-guide-to-exploratory-data-analysis-ddd99a03199e)

# %% [markdown]
# [<a href="#Topics-Covered">Back to top</a>]
#
# ---

# %% [markdown]
# # 3.Mathematical Symbol

# %% [markdown]
# $\sum$
#
# $\forall$
#
# $ y=mx+c $
# $$ y=mx+c $$

# %%
from IPython.display import display,Math,Latex

m,c = 0.5,1 
print('the eqn is')
display(Math(f'y={m}x+{c}'))
# Out:
# the eqn is
# $\displaystyle y=0.5x+1$

# %% [markdown]
# [<a href="#Topics-Covered">Back to top</a>]
#
# ---

# %% [markdown]
# # 4.Line Break

# %% [markdown]
# The line breaks comes here<br>starts form new line

# %% [markdown]
# [<a href="#Topics-Covered">Back to top</a>]
#
# ---

# %% [markdown]
# # 5.Bold and Italic Text

# %% [markdown]
# **Bold**  <br>
# __Bold__
#
# *Italic*  <br>
# _Italic_

# %% [markdown]
# [<a href="#Topics-Covered">Back to top</a>]
#
# ----

# %% [markdown]
# # 6.Horizontal Lines

# %% [markdown]
# ---
#
# __Horizontal lines added above and below.__
#
# ---

# %% [markdown]
# [<a href="#Topics-Covered">Back to top</a>]
#
# ---

# %% [markdown]
# # 7.Ordered List

# %% [markdown]
# 1. Python
# 2. Java
# 3. scala
#
# <ol>
#     <li>Python</li>
#     <li>Java</li>
#     <li>scala</li>
# </ol>

# %% [markdown]
# [<a href="#Topics-Covered">Back to top</a>]
#
# ---

# %% [markdown]
# # 8.Unordered List

# %% [markdown]
# - Python
# - Java
# - scala
#
# <ul>
#     <li>Python</li>
#     <li>Java</li>
#     <li>scala</li>
# </ul>

# %% [markdown]
# [<a href="#Topics-Covered">Back to top</a>]
#
# ---

# %% [markdown]
# # 9.Internal and External Links

# %%
# []() --> This will create a link      [text-to-be-displayed](url)

# For Internal Links --> <a href="#9.Internal-and-External-Links">Internal and External Links</a>

# For Exteranl Links --> <a href="https://twitter.com/home">Visit Twitter</a>

# %% [markdown]
# [[Back to top]](#Topics-Covered) <br>
# [Visit twitter](https://twitter.com)

# %% [markdown]
# <a href="https://twitter.com/home">Visit Twitter</a>
#
# [<a href="#Topics-Covered">Back to top</a>]
#
# ---

# %% [markdown]
# # 10.Image

# %%
# ![]() --> This syntax is to insert a image

# ![ alt-attribute]( url-of-image )

# %% [markdown]
# ![metrics code snippet](attachment:Snap.png)

# %% [markdown]
# <img src='Snap.png' width=700px height=550px >

# %% [markdown]
# [<a href="#Topics-Covered">Back to top</a>]
#
# ---

# %% [markdown]
# # 11.Video

# %%
# Video File
# <video controls src="football.mp4" width=650px height=500px >

# %% [markdown]
# [<a href="#Topics-Covered">Back to top</a>]
#
# ---

# %% [markdown]
# # 12.Other Markdowns

# %% [markdown]
# <div class='alert alert-block alert-success' id='other-markdowns'><strong>Success Alert</strong></div>

# %% [markdown]
# <div class='alert alert-block alert-warning' id='md'><strong>Warning Alert</strong></div>

# %% [markdown]
# <div class='alert alert-block alert-info'><strong>Info Alert</strong></div>

# %% [markdown]
# <div class='alert alert-block alert-info'><strong>Languages Known</strong>
#
# <ul>
#     <li>Python</li>
#     <li>Java</li>
#     <li>C</li>
# </ul>
#
# </div>

# %%
# You can either use the <div></div> or [](  ) for linking.

# %% [markdown]
# <div class="alert alert-block alert-info"><strong>Content</strong></div>
# <div class="list-group">
#     <a class="list-group-item list-group-item-action" href="#other-markdowns">Other Markdowns</a>
#     <a class="list-group-item list-group-item-action" href="#mda">Missing Data Aanalysis</a>
#     <a class="list-group-item list-group-item-action" href="#out">Outliers</a>
#     <a class="list-group-item list-group-item-action" href="#asu">Assumptions</a>
#     <a class="list-group-item list-group-item-action" href="#fsu">Fix Assumptions</a>
#     <a class="list-group-item list-group-item-action" href="#ols">Ordinary Least Squares(OLS)</a>
#     <a class="list-group-item list-group-item-action" href="#mtt">Model Training and Testing</a>
#     <a class="list-group-item list-group-item-action" href="#rf">References</a>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success" id='rf'><strong>References</strong></div>
#
# * https://learningwithdata.com/posts/tylerfolkman/the-ultimate-guide-to-linear-regression/
# * https://www.analyticsvidhya.com/blog/2021/05/all-you-need-to-know-about-your-first-machine-learning-model-linear-regression/
# * https://towardsdatascience.com/the-complete-guide-to-linear-regression-in-python-3d3f8f06bf8
# * https://www.keboola.com/blog/linear-regression-machine-learning
# * https://learningwithdata.com/posts/tylerfolkman/the-ultimate-guide-to-linear-regression/
# * https://www.analyticsvidhya.com/blog/2021/05/all-you-need-to-know-about-your-first-machine-learning-model-linear-regression/
# * https://towardsdatascience.com/the-complete-guide-to-linear-regression-in-python-3d3f8f06bf8
# * https://www.keboola.com/blog/linear-regression-machine-learning
# * https://rstudio-pubs-static.s3.amazonaws.com/57835_c4ace81da9dc45438ad0c286bcbb4224.html
# * https://www.itl.nist.gov/div898/handbook/prc/section1/prc16.htm
# * https://www.kaggle.com/nareshbhat/outlier-the-silent-killer
# * https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba
# * https://community.gooddata.com/metrics-and-maql-kb-articles-43/normality-testing-skewness-and-kurtosis-241
# * https://towardsdatascience.com/methods-for-normality-test-with-application-in-python-bb91b49ed0f5
# * https://medium.com/@TheDataGyan/day-8-data-transformation-skewness-normalization-and-much-more-4c144d370e55
# * https://machinelearningmastery.com/standardscaler-and-minmaxscaler-transforms-in-python/
# * https://medium.com/@TheDataGyan/day-8-data-transformation-skewness-normalization-and-much-more-4c144d370e55
# * https://jyotiyadav99111.medium.com/statistics-how-should-i-interpret-results-of-ols-3bde1ebeec01

# %% [markdown]
# ---
# [For more markdowns](http://localhost:8888/notebooks/DS%20and%20ML/Kaggle/Kaggle%20Important%20Notebooks/how-to-handle-outliers.ipynb)
#
# ---

# %% [markdown]
# <div style='color:black;
#             display:fill;
#             background-color:lightpink;
#             border-radius:7px;
#             font-size:20px;
#             font-family:Georgia;
#             letter-spacing:0.5px'>
#     <p style='padding:15px;font-weight:bold'>Wow this looks cool</p>
# </div>

# %% [markdown]
# <div style='color:black;
#             display:fill;
#             background-color:cyan;
#             border-radius:7px;
#             font-size:20px;
#             font-family:nexa;
#             letter-spacing:0.5px'>
#     <p style='padding:15px;font-weight:bold'>Wow this looks cool</p>
# </div>
